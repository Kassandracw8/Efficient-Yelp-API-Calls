# %% [markdown]
# # Kassandra Howard

# %%
import json
from yelpapi import YelpAPI
import pandas as pd
import os, math, time

# %%
with open('/Users/dhowa/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['Client-ID', 'API Key'])

# %%
yelp_api = YelpAPI(login['API Key'],timeout_s=5.0)
yelp_api

# %%
LOCATION = 'Colorado Springs, CO'
TERM = 'Burgers'

# %%
JSON_FILE = f"Data/results_in_progress_Burgers.json"
JSON_FILE
# Out:
# 'Data/results_in_progress_Burgers.json'

# %%
file_exists = os.path.isfile(JSON_FILE)
 
if file_exists == False:

    folder = os.path.dirname(JSON_FILE)

if len(folder)>0:

    os.makedirs(folder,exist_ok=True)
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")

    with open(JSON_FILE,'w') as f:
        json.dump([],f)  

else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/results_in_progress_Burgers.json not found. Saving empty list to file.

# %%
with open(JSON_FILE, 'r') as f:
    previous_results = json.load(f)

n_results = len(previous_results)
print(f'- {n_results} previous results found.')
# Out:
# - 0 previous results found.

# %%
results = yelp_api.search_query(location='Colorado Springs, CO',
                                       term='Burgers')

# %%
type(results)
# Out:
# dict

# %%
total_results=results['total']
total_results
# Out:
# 559

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['region']
# Out:
# {'center': {'longitude': -104.75738525390625, 'latitude': 38.874816743438615}}

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                           alias  \
# 0   PFC0zCaZSybO9T5vzbu4fA           the-green-line-grill-colorado-springs
# 1   bFkbpRZlz9MoOsiSQhfx3Q                 skirted-heifer-colorado-springs
# 2   AUDAf2embcO1tGhAUKLglw               the-public-house-colorado-springs
# 3   4cHxYgk5F-LqdvWKheu0Jw        bad-daddys-burger-bar-colorado-springs-3
# 4   kzRdZLL_YLM4D787Q24ZQg              aces-burger-bar-colorado-springs-2
# 5   K11SCcDeCAU7rz8m5nl-cQ            drifters-hamburgers-colorado-springs
# 6   sgPr8gJzxW27iknQ7dFhXQ  hops-n-drops-colorado-springs-colorado-springs
# 7   VwA-6xJTaoHML70chXxNuQ                 phantom-canyon-colorado-springs
# 8   hSP7TsNtaFl9FUPlAlxVWQ              brakemans-burgers-colorado-springs
# 9   DlWc8bYq0SG9J32zlgHJrg                      bubbas-33-colorado-springs
# 10  XflGtJb3YAUdY5FJus219w                         shugas-colorado-springs
# 11  4h42qiA4ar6L4E5esu9kjA  grumpy-s-burgers-and-biscuits-colorado-springs
# 12  gI8R7lrEyV38hJcxXrMKGg                    fat-shack-colorado-springs-2
# 13  HxVG2j1yweJYP9T9V42zUg  lazy-dog-restaurant-and-bar-colorado-springs-2
# 14  li8yHssxL8fWDSb_MhEBjQ                         503w-colorado-springs-2
# 15  Yi8ni7S9184dm9j-XxIjhQ               bunzys-and-booze-colorado-springs
# 16  aHqnp1vl0pTPgYX269WSwA                     the-well-colorado-springs-2
# 17  _SopORDhjsRrJ3lomK4nPQ                restaurant-1858-colorado-springs
# 18  Fs8MBqJ5w2XREdq7uWxZ4w        red-leg-brewing-company-colorado-springs
# 19  -MsVWrs7WwYnAtu6UYG5YA                    felipes-109-colorado-springs
#
#                                name  \
# 0              The Green Line Grill
# 1                    Skirted Heifer
# 2                  The Public House
# 3            Bad Daddy's Burger Bar
# 4                   Aces Burger Bar
# 5              Drifter's Hamburgers
# 6   Hops n Drops - Colorado Springs
# 7                    Phantom Canyon
# 8                Brakeman's Burgers
# 9                        Bubba's 33
# 10                          Shuga's
# 11    Grumpy’s Burgers And Biscuits
# 12                        Fat Shack
# 13        Lazy Dog Restaurant & Bar
# 14                             503W
# 15                  Bunzy's & Booze
# 16                         The Well
# 17                  Restaurant 1858
# 18          Red Leg Brewing Company
# 19                     Felipe's 109
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/ngUIZu...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/iM8B1H...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/6ldy6w...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/uxeA2T...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/PFsaaG...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/hII5Tb...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/XH4Tu_...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/V9ogHV...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/7SnsiQ...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/RQ_NcD...      False
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/ni4FhA...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/7QeUKR...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/RAVhpc...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/_AEuXD...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/sTe13b...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/agBToO...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/7irky2...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/cjS6eL...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/W6SxrB...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/RFShta...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/the-green-line-grill-...           428
# 1   https://www.yelp.com/biz/skirted-heifer-colora...          1144
# 2   https://www.yelp.com/biz/the-public-house-colo...           533
# 3   https://www.yelp.com/biz/bad-daddys-burger-bar...           491
# 4   https://www.yelp.com/biz/aces-burger-bar-color...             2
# 5   https://www.yelp.com/biz/drifters-hamburgers-c...           342
# 6   https://www.yelp.com/biz/hops-n-drops-colorado...           207
# 7   https://www.yelp.com/biz/phantom-canyon-colora...          1636
# 8   https://www.yelp.com/biz/brakemans-burgers-col...            93
# 9   https://www.yelp.com/biz/bubbas-33-colorado-sp...           438
# 10  https://www.yelp.com/biz/shugas-colorado-sprin...          1693
# 11  https://www.yelp.com/biz/grumpy-s-burgers-and-...             1
# 12  https://www.yelp.com/biz/fat-shack-colorado-sp...            56
# 13  https://www.yelp.com/biz/lazy-dog-restaurant-a...           489
# 14  https://www.yelp.com/biz/503w-colorado-springs...           617
# 15  https://www.yelp.com/biz/bunzys-and-booze-colo...            23
# 16  https://www.yelp.com/biz/the-well-colorado-spr...            33
# 17  https://www.yelp.com/biz/restaurant-1858-color...           110
# 18  https://www.yelp.com/biz/red-leg-brewing-compa...           182
# 19  https://www.yelp.com/biz/felipes-109-colorado-...            45
#
#                                            categories  rating  \
# 0          [{'alias': 'burgers', 'title': 'Burgers'}]     4.5
# 1   [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 2   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 3   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 4   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
# 5   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 6   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 7   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 8   [{'alias': 'tradamerican', 'title': 'American ...     3.5
# 9   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 10  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.5
# 11  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     5.0
# 12  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     3.5
# 13  [{'alias': 'comfortfood', 'title': 'Comfort Fo...     4.0
# 14  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 15  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 16   [{'alias': 'food_court', 'title': 'Food Court'}]     4.5
# 17  [{'alias': 'newamerican', 'title': 'American (...     3.5
# 18     [{'alias': 'breweries', 'title': 'Breweries'}]     4.5
# 19  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.0
#
#                                           coordinates  \
# 0   {'latitude': 38.8272007, 'longitude': -104.818...
# 1   {'latitude': 38.8370285078266, 'longitude': -1...
# 2   {'latitude': 38.788136, 'longitude': -104.8205...
# 3    {'latitude': 38.96406, 'longitude': -104.793896}
# 4   {'latitude': 38.83132084846157, 'longitude': -...
# 5   {'latitude': 38.89644174733928, 'longitude': -...
# 6     {'latitude': 38.91132, 'longitude': -104.71729}
# 7   {'latitude': 38.834252, 'longitude': -104.824955}
# 8    {'latitude': 38.834068, 'longitude': -104.82897}
# 9   {'latitude': 38.87102, 'longitude': -104.71894...
# 10     {'latitude': 38.8243, 'longitude': -104.82622}
# 11    {'latitude': 38.84627, 'longitude': -104.86175}
# 12  {'latitude': 38.886399, 'longitude': -104.715948}
# 13  {'latitude': 38.9415839, 'longitude': -104.79889}
# 14  {'latitude': 38.83257759845514, 'longitude': -...
# 15     {'latitude': 38.83837, 'longitude': -104.7919}
# 16  {'latitude': 38.833421345530624, 'longitude': ...
# 17    {'latitude': 38.82213, 'longitude': -104.84746}
# 18  {'latitude': 38.8968837, 'longitude': -104.870...
# 19  {'latitude': 38.788305, 'longitude': -104.758677}
#
#                                   transactions price  \
# 0                           [delivery, pickup]     $
# 1                           [delivery, pickup]    $$
# 2                                   [delivery]    $$
# 3                           [delivery, pickup]    $$
# 4                                   [delivery]   NaN
# 5                                   [delivery]     $
# 6                           [delivery, pickup]    $$
# 7   [restaurant_reservation, delivery, pickup]    $$
# 8                                   [delivery]    $$
# 9                                   [delivery]    $$
# 10  [restaurant_reservation, delivery, pickup]    $$
# 11                                          []   NaN
# 12                          [delivery, pickup]    $$
# 13                          [delivery, pickup]    $$
# 14                          [delivery, pickup]    $$
# 15                                          []   NaN
# 16                                          []    $$
# 17                                  [delivery]   $$$
# 18                                          []    $$
# 19                          [delivery, pickup]   NaN
#
#                                              location         phone  \
# 0   {'address1': '230 1/2 Pueblo Ave', 'address2':...  +17199641461
# 1   {'address1': '204 N Tejon', 'address2': '', 'a...  +17196353276
# 2   {'address1': '445 E Cheyenne Mountain Blvd', '...  +17194653079
# 3   {'address1': '1765 Briargate Pkwy', 'address2'...  +17194186845
# 4   {'address1': None, 'address2': None, 'address3...  +17193576665
# 5   {'address1': '4455 Mark Dabling Blvd', 'addres...  +17195488163
# 6   {'address1': '5820 Stetson Hills Blvd', 'addre...  +17195747219
# 7   {'address1': '2 E Pikes Peak Ave', 'address2':...  +17196352800
# 8   {'address1': '10 S Sierra Madre St', 'address2...  +17193758769
# 9   {'address1': '5807 Constitution Ave', 'address...  +17195761223
# 10  {'address1': '702 S Cascade Ave', 'address2': ...  +17193281412
# 11  {'address1': '2407 W Colorado Ave', 'address2'...  +17193577907
# 12  {'address1': '3735 Bloomington St', 'address2'...  +17193758851
# 13  {'address1': '7605 Academy Blvd N', 'address2'...  +17194455851
# 14  {'address1': '503 W Colorado Ave', 'address2':...  +17193588040
# 15  {'address1': '1919 E Boulder St', 'address2': ...  +17192035522
# 16  {'address1': '315 E Pikes Peak Ave', 'address2...  +17194013726
# 17  {'address1': '1045 Lower Gold Camp Rd', 'addre...  +18889658269
# 18  {'address1': '2323 Garden Of The Gods Rd', 'ad...  +17195983776
# 19  {'address1': '3008 S Academy Blvd', 'address2'...  +17193920447
#
#      display_phone      distance
# 0   (719) 964-1461   7500.943939
# 1   (719) 635-3276   7114.841034
# 2   (719) 465-3079  11084.864202
# 3   (719) 418-6845  10413.964844
# 4   (719) 357-6665   6966.451720
# 5   (719) 548-8163   6326.808746
# 6   (719) 574-7219   5321.480768
# 7   (719) 635-2800   7387.654982
# 8   (719) 375-8769   7662.774224
# 9   (719) 576-1223   3354.030649
# 10  (719) 328-1412   8190.069922
# 11  (719) 357-7907   9577.752461
# 12  (719) 375-8851   3811.025392
# 13  (719) 445-5851   8247.141360
# 14  (719) 358-8040   8170.446338
# 15  (719) 203-5522   5045.704243
# 16  (719) 401-3726   7069.935207
# 17  (888) 965-8269   9765.977454
# 18  (719) 598-3776  10075.213470
# 19  (719) 392-0447   9621.361523
